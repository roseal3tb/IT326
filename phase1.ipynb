# %% [markdown]
# <a href="https://colab.research.google.com/github/roseal3tb/IT326/blob/main/phase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Goal
# The goal of this project is to apply data mining techniques on a real-world dataset to analyze the data and derive actionable insights. We aim to use classification and clustering techniques on the selected dataset to uncover hidden patterns and analyze the behavior of the data. In this case, algorithms like Decision Trees and K-Means will be applied for classification and clustering tasks, with performance evaluation using various metrics such as accuracy and the Gini coefficient.

# %% [markdown]
# # Dataset Source
# The dataset was obtained from kaggle.com https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction?resource=download
